# %% [markdown]
# <a href="https://colab.research.google.com/github/mkbahk/QuantumComputing/blob/main/%EC%96%91%EC%9E%90%ED%9A%8C%EB%A1%9C_%EC%88%98%ED%95%99%EA%B8%B0%ED%98%B8_20231103.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -m pip install qiskit[visualization]
# !python -m pip install qiskit-aer

# %% [markdown]
# '0'이 100% 나오는 상태

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector

qc = QuantumCircuit(1)
#qc = QuantumCircuit(2)
#qc = QuantumCircuit(3)

state = Statevector.from_instruction(qc)
print(state.data)
plot_bloch_multivector(state)
# Out:
# [1.+0.j 0.+0.j]

# %% [markdown]
# '1'이 100%인 상태

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector

qc = QuantumCircuit(1, 1)
qc.x(0)

state = Statevector.from_instruction(qc)
print(state.data)
plot_bloch_multivector(state)
# Out:
# [0.+0.j 1.+0.j]

# %%
qc.measure(range(1), range(1))
qc.draw('mpl')

# %%
from qiskit import Aer, execute
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend, shots=1024)
result = job.result()
counts = result.get_counts()
print(counts)

from qiskit.visualization import plot_histogram
plot_histogram(data=counts)
# Out:
# {'1': 1024}

# %%
from qiskit import Aer, execute
qc = QuantumCircuit(1)
qc.x(0)
backend = Aer.get_backend('statevector_simulator')
result = execute(qc, backend).result()
state = result.get_statevector()
print(state)
plot_bloch_multivector(state)
# Out:
# Statevector([3.74939946e-33+6.123234e-17j, 1.00000000e+00+0.000000e+00j],
#             dims=(2,))

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector

qc = QuantumCircuit(1)
qc.h(0)
state = Statevector.from_instruction(qc)
print(state.data)
plot_bloch_multivector(state)
# Out:
# [0.70710678+0.j 0.70710678+0.j]

# %% [markdown]
# Qubit이 2개일 때는

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector

qc = QuantumCircuit(2)

state = Statevector.from_instruction(qc)
print(state.data)
plot_bloch_multivector(state)
# Out:
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j]

# %% [markdown]
# 결과가 10,10으로 나와야 하는데 1000으로 나왔음<br>
# 이 상태에서 한쪽 큐빗만 상태를 변경해 봄

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector

qc = QuantumCircuit(2)
qc.x(0)

state = Statevector.from_instruction(qc)
print(state.data)
plot_bloch_multivector(state)
# Out:
# [0.+0.j 1.+0.j 0.+0.j 0.+0.j]

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector

qc = QuantumCircuit(2)
qc.x(1)

state = Statevector.from_instruction(qc)
print(state.data)
plot_bloch_multivector(state)
# Out:
# [0.+0.j 0.+0.j 1.+0.j 0.+0.j]

# %% [markdown]
# 3Qubit 양자회로-8차원 벡터로 나옴

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector

qc = QuantumCircuit(3)
qc.x(1)

state = Statevector.from_instruction(qc)
print(state.data)
plot_bloch_multivector(state)
# Out:
# [0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]

# %% [markdown]
# 2이상의 Qubit의 연결은 Knonecker Product - a.k.a Tensor Product<br>
# ![스크린샷 2023-11-03 오후 2.01.32.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2023-11-03 오후 3.40.41.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2023-11-03 오후 3.41.42.png](data:image/png;base64,...)

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector

qc = QuantumCircuit(2)
qc.h(range(2))
qc.s(0)
qc.sdg(1)
qc.draw('mpl')

# %%
state = Statevector.from_instruction(qc)
print(state.data)
plot_bloch_multivector(state)
# Out:
# [0.5+0.j  0. +0.5j 0. -0.5j 0.5+0.j ]

# %% [markdown]
# ![스크린샷 2023-11-03 오후 3.51.41.png](data:image/png;base64,...)

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector

qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0, 1)
qc.draw('mpl')

# %%
state = Statevector.from_instruction(qc)
print(state.data)
plot_bloch_multivector(state)
# Out:
# [0.70710678+0.j 0.        +0.j 0.        +0.j 0.70710678+0.j]
