# %% [markdown]
# <a href="https://colab.research.google.com/github/mkbahk/QuantumComputing/blob/main/QuantumCircuit_U_Gate_mkbahk_20251105.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install qiskit[visualization]==1.2.4
# %pip install qiskit-aer==0.15.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 42.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 50.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 MB 15.5 MB/s eta 0:00:00
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=eee2fb080df54e823f47e649ebd9d69c296f81f92c313f16e414fd20bf37b1df
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 59.4 MB/s eta 0:00:00
# ...

# %%
from qiskit import QuantumCircuit
from qiskit.circuit.library import UGate

qc = QuantumCircuit(1)

# U3Gate와 동일한 UGate
theta = 1.0
phi = 0.5
lam = 0.2

qc.append(UGate(theta, phi, lam), [0])
qc.draw('mpl')

# %%
from qiskit.quantum_info import Operator
U3_matrix = Operator(qc).data
Operator(qc).draw

# %%
print(U3_matrix )
# Out:
# [[ 0.87758256+0.j         -0.46986895-0.09524715j]
#  [ 0.42073549+0.22984885j  0.67121217+0.56535421j]]

# %%
from qiskit.circuit.library.standard_gates import U3Gate

qc2 = QuantumCircuit(1)
qc2.append(U3Gate(theta, phi, lam), [0])
qc2.draw('mpl')

# %%
print(U3)
